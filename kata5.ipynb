# %% [markdown]
# # Adcion (Suma)
# answer = 30 + 12, print(answer) ,salida: 42
#
# # Sustraccion(Resta)
# difference = 30 - 12, print(difference), salida: 18
#
# # Multiplicacion
# product = 30 * 12, print(product), salida: 360
#
# # Division
# quotient = 30 / 12. print(quotient), salida: 2.5
#
# # Trabajar con la division
# seconds = 1042, display_minutes = 1042 // 60, print(display_minutes), salida: 17
#
# seconds = 1042, display_minutes = 1042 // 60, display_seconds = 1042 % 60
#
# print(display_minutes)
#
# print(display_seconds)
#
# salida: 17, 22
#
# # Orden de funcionamiento (Jerarquía de Operaciones)
# result_1 = 1032 + 26 * 2
#
# result_2 = 1032 + (26 * 2)
#
# El resultado es el mismo en ambos casos - 1084
#
# # Convertir cadenas en números
# demo_int = int('215')
#
# print(demo_int)
#
# //////////////////////
#
# demo_float = float('215.3')
#
# print(demo_float)
#
# Valores absolutos
# print(abs(39 - 16))
#
# print(abs(16 - 39))
#
# # Redondeo
# print(round(14.5))
#
# # Biblioteca Math
# from math import ceil, floor
#
# round_up = ceil(12.5)
#
# print(round_up)
#
# round_down = floor(12.5)
#
# print(round_down)
#
# Salida: 13, 12

# %%
# Ejercicio1  Utilizar operadores aritmeticos
# Distancia entre dos planetas
Tierra = 149597870
Jupiter = 778547200
difference = Jupiter - Tierra
print(difference, "km de distancia")

# Distanica km a millas
print(difference * 1.609344, "millas de distancia")

# %%
# Ejercicio 2 - Convierte cadenas en numeros y usa valores absolutos

#Distancia entre dos planetas
planeta1 = input('Introduzca la distancia del sol para el primer planeta en KM')
planeta2 = input('Introduzca la distancia del sol para el segundo planeta en KM')

# Convierte las cadenas en numeros
planeta1 = int(planeta1)
planeta2 = int(planeta2)

# Determinar el valor absoluto
distancia_km = planeta2 - planeta1
print(distancia_km)

# Distancia km a millas
distancia_mi = distancia_km * 1.609344
print(distancia_mi)
